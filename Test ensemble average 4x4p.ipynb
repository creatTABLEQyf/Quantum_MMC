# %%
import qiskit
from qiskit import assemble, QuantumCircuit
from qiskit.visualization import plot_histogram
from qiskit.compiler import transpile
from random import *
from qiskit import Aer
sim = Aer.get_backend("statevector_simulator")
import numpy as np
from qiskit.circuit.library.standard_gates import HGate
from qiskit.circuit.library import RZGate, RYGate
import matplotlib.pyplot as plt

import time
from IPython.display import clear_output

# %%
def neighbor_list(i, j, N):
  a = i-1
  b = j-1
  c = i+1 
  d = j+1 
  if a < 0: 
      a = N-1
  if b < 0: 
      b = N-1
  if c > N-1: 
      c = 0 
  if d > N-1: 
      d = 0
  left   = (a, j)
  above  = (i, b)
  right  = (c, j)
  below  = (i, d)
  return [left, above, right, below]

# %%
def lat_qc(i, temp): 
    global N
    spin = N**2
    
    # J = 1
    prob1= np.exp(-8/temp)
    angle1 = 2*np.arccos(np.sqrt(prob1))
    prob2 = np.exp(-4/temp)
    angle2 = 2*np.arccos(np.sqrt(prob2))

    ### construct neighbor qubit 
    ising = np.arange(0, N**2).reshape(N,N)
    index = np.where(i==ising)
    neighbor_qubit = []
    for k in neighbor_list(index[0], index[1],N):
        neighbor_qubit.append(ising[k][0])
    ### construct circuit 
    qc = QuantumCircuit(spin+4, spin)
    aux_qubit = [spin, spin+1, spin+2, spin+3]
    # flip first 
    qc.x(i)
    qc.barrier()

    # store sign information
    for j in range(4): 
        qc.cx(i, aux_qubit[j])
        qc.cx(neighbor_qubit[j], aux_qubit[j])

    # rotate or not depends on sign
    #####################situation 1 : all same signs #####################
    [aux1, aux2, aux3, aux4] = aux_qubit
    # default is ferromagnetic
    mcry= RYGate(angle1).control(4,label=None )
    # for antiferromagnetic add the line below
    # mcry._ctrl_state=0
    qc.append(mcry,[aux1, aux2, aux3, aux4, i])

    #####################situation 2 : 3 same(different) signs, 1 different (same) signs #####################
    # implementation (entanglement) will be different depends on the system is FM or AFM 
    mcry_1= RYGate(angle2).control(4,label=None )
    mcry_2= RYGate(angle2).control(4,label=None )
    mcry_3= RYGate(angle2).control(4,label=None )
    mcry_4= RYGate(angle2).control(4,label=None )

    # ferromagnetic  
    mcry_1._ctrl_state=14
    mcry_2._ctrl_state=13
    mcry_3._ctrl_state=11
    mcry_4._ctrl_state=7

    # antiferromagnetic 
    # mcry_1._ctrl_state=1
    # mcry_2._ctrl_state=2
    # mcry_3._ctrl_state=4
    # mcry_4._ctrl_state=8

    qc.append(mcry_1, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_2, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_3, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_4, [aux1, aux2, aux3, aux4, i])
    qc.barrier()
    # measure
    for i in range(spin): 
        qc.measure(i,i)
    return qc

def get_2d_qc(spin, temp):  
    # get all possible circuit
    qc_info=[]
    for i in range(spin):
        qc_info.append(lat_qc(i, temp))
    return qc_info
def measure_state(qc, sim): 
    qc = transpile(qc,sim)
    final_counts = sim.run(qc, shot=1).result().get_counts()
    return final_counts.keys()

def map_state(final_state, spin):
    state = np.zeros(spin)
    for i in final_state:
        for j,k in enumerate(i): 
            if k == '1': 
                state[j] = k 
    return state
    
def magnetization(eq_state):
    ans = 0
    size = len(eq_state)
    for num in eq_state:
        if num == '1':
            ans += 1
        elif num == '0':
            ans -= 1
    return abs(ans)/float(size)    

def MC_sweep_2D(start, runs, qc_info, sim):
    global spin, N
    qc = start
    # pyplot.figure(figsize=(5,5))
    plt.ion()
    states = []
    mag = []
    times = []
    for run in range(runs):
        ti
        # randomly pick site
        pick = randint(1, spin)
        circuit = qc_info[pick-1]
        qc.compose(circuit, inplace=True)
        # print(qc)
        state = measure_state(qc,sim)
        state_string = list(state)[0]
        states.append(state_string)
        mag.append(magnetization(state_string))
        # run the next MC with previous state
        qc = QuantumCircuit(spin+4, spin)
        
       
        clear_output(wait=True)
        plt.imshow(map_state(state, spin).reshape(N,N))
        # pyplot.show()
        plt.show()
    
        for i in state: 
            for j, k in enumerate(i): 
                if k == '1': 
                    qc.x(spin-1-j)
    return states, mag

# %%
# global information
N = 4
spin = N**2

# %%
# %%time
# FM ensemble average
temps = np.linspace(0.01, 20, 20)
mag_values = []
std_values = []
for temp in temps:
    info = get_2d_qc(spin,temp)
    cold_lat = QuantumCircuit(spin+4, spin)
    # equilibrium run : 512
    states, mag = MC_sweep_2D(cold_lat, 512, info, sim)
    mag_values.append(np.mean(mag))
    std_values.append(np.std(mag))
# Out:
# CPU times: user 6h 58min 32s, sys: 3h 29min 39s, total: 10h 28min 11s
# Wall time: 1h 49min 35s

# %%
plt.errorbar(temps, mag_values, std_values, linestyle='dashdot', marker='^')
plt.xlabel('kT')
plt.ylabel('magnetization')
plt.title('4x4 with PBC, starting at a FM case')
plt.grid()
plt.show()

# %%
# %%time
# Convergence
temps = np.linspace(10, 10, 1)
mag_values = []
std_values = []
for temp in temps:
    info = get_2d_qc(spin,temp)
    cold_lat = QuantumCircuit(spin+4, spin)
    # equilibrium run : 512
    states, mag = MC_sweep_2D(cold_lat, 512, info, sim)
    mag_values.append(np.mean(mag))
    std_values.append(np.std(mag))
# Out:
# CPU times: user 20min 28s, sys: 9min 41s, total: 30min 9s
# Wall time: 5min 35s

# %%
plt.figure(dpi = 250)
plt.plot(mag, linestyle = '--', marker = '.')

# %%
plt.figure(dpi = 250)
plt.hist(mag)
# Out:
# (array([ 57., 123., 121.,   0.,  91.,  65.,   0.,  33.,  17.,   5.]),
#  array([0.    , 0.0875, 0.175 , 0.2625, 0.35  , 0.4375, 0.525 , 0.6125,
#         0.7   , 0.7875, 0.875 ]),
#  <BarContainer object of 10 artists>)

# %%
std_with_sample = []
for i in range(len(mag)):
    std_with_sample.append(np.std(mag[:i]))
    
plt.figure(dpi = 250)
plt.plot(std_with_sample)
plt.xlabel('Number of Samples')
plt.ylabel('Standard Deviation')
plt.title('kT = 10')
plt.grid()

# %%
# %%time
# Convergence
temps = np.linspace(10, 10, 1)
mag_values = []
std_values = []
for temp in temps:
    info = get_2d_qc(spin,temp)
    cold_lat = QuantumCircuit(spin+4, spin)
    # equilibrium run : 512
    states, mag = MC_sweep_2D(cold_lat, 512, info, sim)
    mag_values.append(np.mean(mag))
    std_values.append(np.std(mag))
    
std_with_sample = []
for i in range(len(mag)):
    std_with_sample.append(np.std(mag[:i]))
    
plt.figure(dpi = 250)
plt.plot(std_with_sample)
plt.xlabel('Number of Samples')
plt.ylabel('Standard Deviation')
plt.title('kT = 10')
plt.grid()
# Out:
# CPU times: user 19min 57s, sys: 10min 30s, total: 30min 27s
# Wall time: 5min 20s

# %%
plt.figure(dpi = 250)
plt.plot(std_with_sample, label = 'STD')
plt.plot(np.linspace(10, 512, 1000), 1/np.linspace(10, 512, 1000)+0.18, label = r'$\frac{1}{N}$+0.18')
plt.plot(np.linspace(10, 512, 1000), 1/np.sqrt(np.linspace(10, 512, 1000))+0.12, label = r'$\frac{1}{\sqrt{N}}$+0.12')
plt.xlabel('Number of Samples')
plt.ylabel('Standard Deviation')
plt.title('kT = 10')
plt.legend()
plt.grid()

# %%
# import matplotlib.animation as animation
# make an animation showing the change of distribution?
