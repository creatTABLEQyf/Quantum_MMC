# %%
import qiskit
from qiskit import assemble, QuantumCircuit
from qiskit.visualization import plot_histogram
from qiskit.compiler import transpile
from random import *
from qiskit import Aer
sim = Aer.get_backend("statevector_simulator")
import numpy as np
import pandas as pd
from qiskit.circuit.library.standard_gates import HGate
from qiskit.circuit.library import RZGate, RYGate
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def neighbor_list(i, j, N):
  a = i-1
  b = j-1
  c = i+1 
  d = j+1 
  if a < 0: 
      a = N-1
  if b < 0: 
      b = N-1
  if c > N-1: 
      c = 0 
  if d > N-1: 
      d = 0
  left   = (a, j)
  above  = (i, b)
  right  = (c, j)
  below  = (i, d)
  return [left, above, right, below]

# %%
spin, N = 16, 4

# %%
def single_step_qc(i, temp): 
    global N, spin 
    prob1= np.exp(-8/temp)
    angle1 = 2*np.arccos(np.sqrt(prob1))
    prob2 = np.exp(-4/temp)
    angle2 = 2*np.arccos(np.sqrt(prob2))
    ### construct neighbor qubit 
    ising = np.arange(0, N**2).reshape(N,N)
    index = np.where(i==ising)
    neighbor_qubit = []
    for k in neighbor_list(index[0], index[1],N):
        neighbor_qubit.append(ising[k][0])
    ### construct circuit 
    qc = QuantumCircuit(spin+4)
    aux_qubit = [spin, spin+1, spin+2, spin+3]
    # flip first 
    qc.x(i)
    qc.barrier()
    for j in range(4): 
        qc.cx(i, aux_qubit[j])
        qc.cx(neighbor_qubit[j], aux_qubit[j])
    # rotate or not depends on sign
    #####################situation 1 : all same signs #####################
    [aux1, aux2, aux3, aux4] = aux_qubit
    # default is ferromagnetic
    mcry= RYGate(angle1).control(4,label=None )
    qc.append(mcry,[aux1, aux2, aux3, aux4, i])
    #####################situation 2 : 3 same signs, 1 different signs #####################
    mcry_1= RYGate(angle2).control(4,label=None )
    mcry_2= RYGate(angle2).control(4,label=None )
    mcry_3= RYGate(angle2).control(4,label=None )
    mcry_4= RYGate(angle2).control(4,label=None )
    mcry_1._ctrl_state=14
    mcry_2._ctrl_state=13
    mcry_3._ctrl_state=11
    mcry_4._ctrl_state=7
    qc.append(mcry_1, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_2, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_3, [aux1, aux2, aux3, aux4, i])
    qc.append(mcry_4, [aux1, aux2, aux3, aux4, i])
    qc.barrier()
    return qc

# %%
def cal_M(state):
    M = 0
    for i in state:
        if i == '1': 
            M += 1
        else: 
            M -= 1 
    return M/16

# %%
def phase_space_sweep(temp, circuit_size = 32):
    # MC_sweep
    qc = QuantumCircuit(spin+4)
    # for 4x4 ising model at least need to repeat 16 circuits to get all basis (2**16)
    # I used 32 to make sure that we can cover the whole phase space
    # could change this number
    for _ in range(circuit_size):
        pick = randint(0, spin-1)
        qc.compose(single_step_qc(pick, temp), inplace=True)
    return qc

# %%
def measure(circuit):
    circuit.remove_final_measurements()
    circuit.measure_all()
    backend = Aer.get_backend('aer_simulator')
    circuit = transpile(circuit, backend )
    final_counts = backend.run(circuit, shots=8192).result().get_counts()
    print(final_counts)
    state = max(final_counts, key= final_counts.get)[4:]
    mag = abs(cal_M(state))
    print("Most probably state: ", state)
    print("Magnetization: ", mag) 
    return state, mag

# %%
for _ in range(5):
    qc = phase_space_sweep(4)
    measure(qc)
# Out:
# Most probably state:  0111111100010000
# Magnetization:  0.0
# Most probably state:  0001111110110010
# Magnetization:  0.125
# Most probably state:  1100110001100101
# Magnetization:  0.0
# Most probably state:  0100101110101110
# Magnetization:  0.125
# Most probably state:  0001110110111111
# Magnetization:  0.375

# %%
# Average of many results from circuit size 32
temps = np.linspace(0.01, 15, 20)
df = pd.DataFrame()

for temp in temps:
    magnetization = []
    for i in range(10):
        qc = phase_space_sweep(temp)
        state, mag = measure(qc)
        magnetization.append(mag)
    df['kT='+str(temp)] = magnetization

df.to_csv('Circuit 32_Samples 10_statevector.csv')
# Out:
# Most probably state:  0111111111100010
# Magnetization:  0.375
# Most probably state:  0100010010101111
# Magnetization:  0.0
# Most probably state:  0110110001001100
# Magnetization:  0.125
# Most probably state:  0110000001110111
# Magnetization:  0.0
# Most probably state:  0000000000110101
# Magnetization:  0.5
# Most probably state:  1011110000110110
# Magnetization:  0.125
# Most probably state:  1011001101001011
# Magnetization:  0.125
# Most probably state:  0100001000111100
# Magnetization:  0.25
# Most probably state:  0100010110100001
# Magnetization:  0.25
# Most probably state:  1010100110000000
# Magnetization:  0.375
# Most probably state:  1011000101001111
# Magnetization:  0.125
# Most probably state:  0001101010100011
# Magnetization:  0.125
# Most probably state:  1100000011100001
# Magnetization:  0.25
# Most probably state:  0101001010100100
# Magnetization:  0.25
# Most probably state:  0011010001110111
# Magnetization:  0.125
# Most probably state:  1001101101101000
# Magnetization:  0.0
# Most probably state:  0001010100010011
# Magnetization:  0.25
# Most probably state:  0110101010101010
# Magnetization:  0.0
# Most probably state:  1100101101100010
# Magnetization:  0.0
# Most probably state:  0000100110100100
# Magnetization:  0.375
# Most probably state:  1000001110000000
# Magnetization:  0.5
# Most probably state:  0110010111111000
# Magnetization:  0.125
# Most probably state:  0001001011110100
# Magnetization:  0.125
# Most probably state:  0100110110010100
# Magnetization:  0.125
# Most probably state:  0111010100100001
# Magnetization:  0.125
# Most probably state:  1101011111111010
# Magnetization:  0.5
# Most probably state:  0110010010001111
# Magnetization:  0.0
# Most probably state:  1001011110100010
# Magnetization:  0.0
# Most probably state:  1100101110011110
# Magnetization:  0.25
# Most probably state:  0111110111101000
# Magnetization:  0.25
# Most probably state:  1011101010100010
# Magnetization:  0.0
# Most probably state:  0111000111110010
# Magnetization:  0.125
# Most probably state:  1100111111000110
# Magnetization:  0.25
# Most probably state:  0111110010000111
# Magnetization:  0.125
# Most probably state:  1110110101010101
# Magnetization:  0.25
# Most probably state:  1001000100000011
# Magnetization:  0.375
# Most probably state:  1010101100010011
# Magnetization:  0.0
# Most probably state:  0010111100100011
# Magnetization:  0.0
# Most probably state:  0000001010111111
# Magnetization:  0.0
# Most probably state:  0110010100010100
# Magnetization:  0.25
# Most probably state:  0001100110010110
# Magnetization:  0.125
# Most probably state:  1100001010110010
# Magnetization:  0.125
# Most probably state:  1001110101111000
# Magnetization:  0.125
# Most probably state:  0100110100000000
# Magnetization:  0.5
# Most probably state:  1000100010001010
# Magnetization:  0.375
# Most probably state:  0000101011000011
# Magnetization:  0.25
# Most probably state:  1011000110111110
# Magnetization:  0.25
# Most probably state:  0010001111000001
# Magnetization:  0.25
# Most probably state:  1110110100010011
# Magnetization:  0.125
# Most probably state:  0000010111011110
# Magnetization:  0.0
# Most probably state:  0000011100010010
# Magnetization:  0.375
# Most probably state:  1000001001000001
# Magnetization:  0.5
# Most probably state:  1101010101110111
# Magnetization:  0.375
# Most probably state:  0010101111010110
# Magnetization:  0.125
# Most probably state:  1101100010111011
# Magnetization:  0.25
# Most probably state:  1010111110100111
# Magnetization:  0.375
# Most probably state:  0110011000110010
# Magnetization:  0.125
# Most probably state:  1110100111001111
# Magnetization:  0.375
# Most probably state:  0011001011000101
# Magnetization:  0.125
# Most probably state:  1001001001001011
# Magnetization:  0.125
# Most probably state:  0010001111011011
# Magnetization:  0.125
# Most probably state:  0111001010010101
# Magnetization:  0.0
# Most probably state:  1111011110010111
# Magnetization:  0.5
# Most probably state:  0101010011100100
# Magnetization:  0.125
# Most probably state:  0011100011011111
# Magnetization:  0.25
# Most probably state:  1111000011111110
# Magnetization:  0.375
# Most probably state:  0011100110000110
# Magnetization:  0.125
# Most probably state:  0111011110110010
# Magnetization:  0.25
# Most probably state:  1111001010000011
# Magnetization:  0.0
# Most probably state:  1111101000011000
# Magnetization:  0.0
# Most probably state:  1111111011001111
# Magnetization:  0.625
# Most probably state:  1000011101011010
# Magnetization:  0.0
# Most probably state:  0001000001011011
# Magnetization:  0.25
# Most probably state:  0000100010011111
# Magnetization:  0.125
# Most probably state:  0100001111000000
# Magnetization:  0.375
# Most probably state:  1011100011001100
# Magnetization:  0.0
# Most probably state:  0000110111110101
# Magnetization:  0.125
# Most probably state:  1000011010100010
# Magnetization:  0.25
# Most probably state:  1110001111000111
# Magnetization:  0.25
# Most probably state:  1001110110011010
# Magnetization:  0.125
# Most probably state:  0010101110010010
# Magnetization:  0.125
# Most probably state:  0100101010010001
# Magnetization:  0.25
# Most probably state:  0001111101001110
# Magnetization:  0.125
# Most probably state:  1011111111100001
# Magnetization:  0.375
# Most probably state:  0101000001000000
# Magnetization:  0.625
# Most probably state:  0010001100111101
# Magnetization:  0.0
# Most probably state:  1000010010010101
# Magnetization:  0.25
# Most probably state:  0010001000010101
# Magnetization:  0.375
# Most probably state:  1001100010101011
# Magnetization:  0.0
# Most probably state:  1101000010100001
# Magnetization:  0.25
# Most probably state:  1111001000010110
# Magnetization:  0.0
# Most probably state:  1101100010110101
# Magnetization:  0.125
# Most probably state:  0111001011110111
# Magnetization:  0.375
# Most probably state:  0010100010111101
# Magnetization:  0.0
# Most probably state:  0010110111101100
# Magnetization:  0.125
# Most probably state:  0011001000011110
# Magnetization:  0.125
# Most probably state:  1110101010100100
# Magnetization:  0.0
# Most probably state:  0110100111001110
# Magnetization:  0.125
# Most probably state:  1000000100100011
# Magnetization:  0.375
# Most probably state:  1110111000101001
# Magnetization:  0.125
# Most probably state:  0000110000010100
# Magnetization:  0.5
# Most probably state:  1000110011010001
# Magnetization:  0.125
# Most probably state:  0101001001011011
# Magnetization:  0.0
# Most probably state:  1100011001110000
# Magnetization:  0.125
# Most probably state:  1011011001001100
# Magnetization:  0.0
# Most probably state:  0101100010010100
# Magnetization:  0.25
# Most probably state:  1111100001001101
# Magnetization:  0.125
# Most probably state:  1100011000000101
# Magnetization:  0.25
# Most probably state:  0010001110010101
# Magnetization:  0.125
# Most probably state:  0001101101001110
# Magnetization:  0.0
# Most probably state:  1101100011101111
# Magnetization:  0.375
# Most probably state:  1101011000110001
# Magnetization:  0.0
# Most probably state:  1010011100010000
# Magnetization:  0.25
# Most probably state:  1101000000111111
# Magnetization:  0.125
# Most probably state:  1110011100010101
# Magnetization:  0.125
# Most probably state:  1100100010111010
# Magnetization:  0.0
# Most probably state:  1101010001010011
# Magnetization:  0.0
# Most probably state:  0001101000101000
# Magnetization:  0.375
# Most probably state:  1001110000010011
# Magnetization:  0.125
# Most probably state:  1000110001011110
# Magnetization:  0.0
# Most probably state:  1100100100011100
# Magnetization:  0.125
# Most probably state:  0011011101101011
# Magnetization:  0.25
# Most probably state:  1111000111010010
# Magnetization:  0.125
# Most probably state:  0111001111111100
# Magnetization:  0.375
# Most probably state:  0100000001001001
# Magnetization:  0.5
# Most probably state:  1010110000000000
# Magnetization:  0.5
# Most probably state:  0101011100000000
# Magnetization:  0.375
# Most probably state:  0111110011011000
# Magnetization:  0.125
# Most probably state:  0011100010100101
# Magnetization:  0.125
# Most probably state:  0110111010100000
# Magnetization:  0.125
# Most probably state:  1001110110000101
# Magnetization:  0.0
# Most probably state:  1110100001100101
# Magnetization:  0.0
# Most probably state:  1101001110111001
# Magnetization:  0.25
# Most probably state:  0110101110000000
# Magnetization:  0.25
# Most probably state:  0100111010111000
# Magnetization:  0.0
# Most probably state:  1000001110010000
# Magnetization:  0.375
# Most probably state:  1000000101010010
# Magnetization:  0.375
# Most probably state:  1101011011011000
# Magnetization:  0.125
# Most probably state:  0000001101100010
# Magnetization:  0.375
# Most probably state:  0010100011010101
# Magnetization:  0.125
# Most probably state:  1100101101010100
# Magnetization:  0.0
# Most probably state:  1110011011010100
# Magnetization:  0.125
# Most probably state:  1001100001110011
# Magnetization:  0.0
# Most probably state:  1001111101111101
# Magnetization:  0.5
# Most probably state:  1001100001010010
# Magnetization:  0.25
# Most probably state:  0011001011001010
# Magnetization:  0.125
# Most probably state:  0000111110101001
# Magnetization:  0.0
# Most probably state:  0111011011011111
# Magnetization:  0.5
# Most probably state:  1101000111101100
# Magnetization:  0.125
# Most probably state:  0110001111110100
# Magnetization:  0.125
# Most probably state:  1000001100101011
# Magnetization:  0.125
# Most probably state:  1011011100110100
# Magnetization:  0.125
# Most probably state:  1011001111000101
# Magnetization:  0.125
# Most probably state:  1110101001001100
# Magnetization:  0.0
# Most probably state:  1011101001111111
# Magnetization:  0.5
# Most probably state:  1000110000110110
# Magnetization:  0.125
# Most probably state:  1100100000011110
# Magnetization:  0.125
# Most probably state:  1011100001110011
# Magnetization:  0.125
# Most probably state:  1100100111101111
# Magnetization:  0.375
# Most probably state:  0010010100101100
# Magnetization:  0.25
# Most probably state:  1011101101110000
# Magnetization:  0.125
# Most probably state:  1101010001000110
# Magnetization:  0.125
# Most probably state:  0001101000011101
# Magnetization:  0.125
# Most probably state:  0100000001101001
# Magnetization:  0.375
# Most probably state:  1111111100011011
# Magnetization:  0.5
# Most probably state:  1011110010111010
# Magnetization:  0.25
# Most probably state:  0100110101010111
# Magnetization:  0.125
# Most probably state:  1001111111110011
# Magnetization:  0.5
# Most probably state:  0101110001110101
# Magnetization:  0.125
# Most probably state:  0110010000110110
# Magnetization:  0.125
# Most probably state:  1000010000001100
# Magnetization:  0.5
# Most probably state:  1110011100101111
# Magnetization:  0.375
# Most probably state:  0111111110100000
# Magnetization:  0.125
# Most probably state:  1111101111011100
# Magnetization:  0.5
# Most probably state:  0011101101000010
# Magnetization:  0.125
# Most probably state:  1000111111111000
# Magnetization:  0.25
# Most probably state:  0100110000111010
# Magnetization:  0.125
# Most probably state:  0000010011100101
# Magnetization:  0.25
# Most probably state:  0001100001001110
# Magnetization:  0.25
# Most probably state:  0110101011100001
# Magnetization:  0.0
# Most probably state:  0110010100100101
# Magnetization:  0.125
# Most probably state:  1000000100100011
# Magnetization:  0.375
# Most probably state:  1010010000100011
# Magnetization:  0.25
# Most probably state:  0111011111110111
# Magnetization:  0.625
# Most probably state:  1100111001010101
# Magnetization:  0.125
# Most probably state:  0101000110010010
# Magnetization:  0.25
# Most probably state:  0000011001101101
# Magnetization:  0.125
# Most probably state:  1010001011011111
# Magnetization:  0.25
# Most probably state:  1001110101100010
# Magnetization:  0.0
# Most probably state:  0111100001011100
# Magnetization:  0.0
# Most probably state:  1010001110011010
# Magnetization:  0.0
# Most probably state:  0101011011110110
# Magnetization:  0.25
# Most probably state:  0111011101010011
# Magnetization:  0.25
# Most probably state:  0111110011010111
# Magnetization:  0.375
# Most probably state:  1000111010010000
# Magnetization:  0.25
# Most probably state:  1110111100110100
# Magnetization:  0.25
# Most probably state:  1001101011010110
# Magnetization:  0.125
# Most probably state:  0011100000111001
# Magnetization:  0.125
# Most probably state:  0111110001111001
# Magnetization:  0.25
# Most probably state:  0011011100111001
# Magnetization:  0.125

# %%
# Average of many results from circuit size 32
temps = np.linspace(0.01, 15, 20)
df = pd.DataFrame()

for temp in temps:
    magnetization = []
    for i in range(10):
        qc = phase_space_sweep(temp, 64)
        state, mag = measure(qc)
        magnetization.append(mag)
    df['kT='+str(temp)] = magnetization

df.to_csv('Circuit 64_Samples 10_statevector.csv')
# Out:
# Most probably state:  0000111111000101
# Magnetization:  0.0
# Most probably state:  1100000001011001
# Magnetization:  0.25
# Most probably state:  1100010010001001
# Magnetization:  0.25
# Most probably state:  1000101001001011
# Magnetization:  0.125
# Most probably state:  1101011100101111
# Magnetization:  0.375
# Most probably state:  1001000001111110
# Magnetization:  0.0
# Most probably state:  0101000010110010
# Magnetization:  0.25
# Most probably state:  0011000011010100
# Magnetization:  0.25
# Most probably state:  1001000001000000
# Magnetization:  0.625
# Most probably state:  1001101101010000
# Magnetization:  0.125
# Most probably state:  0100101010100010
# Magnetization:  0.25
# Most probably state:  1010010110011011
# Magnetization:  0.125
# Most probably state:  0111100101010011
# Magnetization:  0.125
# Most probably state:  0100000101100110
# Magnetization:  0.25
# Most probably state:  1110101011001100
# Magnetization:  0.125
# Most probably state:  0101010110010011
# Magnetization:  0.0
# Most probably state:  0010010100110100
# Magnetization:  0.25
# Most probably state:  0001100010101000
# Magnetization:  0.375
# Most probably state:  1010011110010010
# Magnetization:  0.0
# Most probably state:  1010000001111000
# Magnetization:  0.25
# Most probably state:  0010111000100010
# Magnetization:  0.25
# Most probably state:  1101010101101100
# Magnetization:  0.125
# Most probably state:  0010001011000001
# Magnetization:  0.375
# Most probably state:  0011111001100001
# Magnetization:  0.0
# Most probably state:  0001100011100001
# Magnetization:  0.25
# Most probably state:  1010000010111001
# Magnetization:  0.125
# Most probably state:  0011110001101110
# Magnetization:  0.125
# Most probably state:  1001010110110010
# Magnetization:  0.0
# Most probably state:  0001100100110110
# Magnetization:  0.125
# Most probably state:  0000110011110111
# Magnetization:  0.125
# Most probably state:  0110011100010011
# Magnetization:  0.0
# Most probably state:  1111101010010000
# Magnetization:  0.0
# Most probably state:  1001001101000000
# Magnetization:  0.375
# Most probably state:  1001010010011001
# Magnetization:  0.125
# Most probably state:  0101001001101100
# Magnetization:  0.125
# Most probably state:  1011000101111110
# Magnetization:  0.25
# Most probably state:  0011111110001010
# Magnetization:  0.125
# Most probably state:  0001001011100010
# Magnetization:  0.25
# Most probably state:  1110010011010101
# Magnetization:  0.125
# Most probably state:  0100101110011001
# Magnetization:  0.0
# Most probably state:  0010110001111001
# Magnetization:  0.0
# Most probably state:  0000000101000101
# Magnetization:  0.5
# Most probably state:  1001001111000000
# Magnetization:  0.25
# Most probably state:  0100001010010001
# Magnetization:  0.375
# Most probably state:  1011110101100101
# Magnetization:  0.25
# Most probably state:  1011101100011000
# Magnetization:  0.0
# Most probably state:  0010011100110110
# Magnetization:  0.0
# Most probably state:  1110001000001001
# Magnetization:  0.25
# Most probably state:  1100101101011000
# Magnetization:  0.0
# Most probably state:  0111101110111011
# Magnetization:  0.5
# Most probably state:  1100010000001100
# Magnetization:  0.375
# Most probably state:  0011111001001001
# Magnetization:  0.0
# Most probably state:  0100010000010000
# Magnetization:  0.625
# Most probably state:  1110111010000110
# Magnetization:  0.125
# Most probably state:  0011011101110100
# Magnetization:  0.125
# Most probably state:  1111001111100010
# Magnetization:  0.25
# Most probably state:  1101101111010100
# Magnetization:  0.25
# Most probably state:  0111001010010001
# Magnetization:  0.125
# Most probably state:  1001110011110011
# Magnetization:  0.25
# Most probably state:  1111100100000110
# Magnetization:  0.0
# Most probably state:  0001111010101010
# Magnetization:  0.0
# Most probably state:  1111011110000000
# Magnetization:  0.0
# Most probably state:  1000001001100110
# Magnetization:  0.25
# Most probably state:  0100000001000101
# Magnetization:  0.5
# Most probably state:  1111000010100110
# Magnetization:  0.0
# Most probably state:  1000001011110011
# Magnetization:  0.0
# Most probably state:  1000100000001011
# Magnetization:  0.375
# Most probably state:  0110110010101101
# Magnetization:  0.125
# Most probably state:  0100000000100100
# Magnetization:  0.625
# Most probably state:  0111100100111011
# Magnetization:  0.25
# Most probably state:  0101100000101111
# Magnetization:  0.0
# Most probably state:  0011100000110100
# Magnetization:  0.25
# Most probably state:  0100000100000010
# Magnetization:  0.625
# Most probably state:  0111100010001001
# Magnetization:  0.125
# Most probably state:  0100001001110001
# Magnetization:  0.25
# Most probably state:  0011001001000111
# Magnetization:  0.125
# Most probably state:  0110100001010101
# Magnetization:  0.125
# Most probably state:  1110110001101010
# Magnetization:  0.125
# Most probably state:  1100010110101111
# Magnetization:  0.25
# Most probably state:  1100100000001100
# Magnetization:  0.375
# Most probably state:  1110110010001010
# Magnetization:  0.0
# Most probably state:  0010101110101101
# Magnetization:  0.125
# Most probably state:  0010100111101010
# Magnetization:  0.0
# Most probably state:  0010101110000011
# Magnetization:  0.125
# Most probably state:  1111111111001101
# Magnetization:  0.625
# Most probably state:  0100011110011001
# Magnetization:  0.0
# Most probably state:  1111101111011110
# Magnetization:  0.625
# Most probably state:  1110111000011101
# Magnetization:  0.25
# Most probably state:  0010100100011001
# Magnetization:  0.25
# Most probably state:  1101000110011110
# Magnetization:  0.125
# Most probably state:  1001100111001000
# Magnetization:  0.125
# Most probably state:  1000100001111011
# Magnetization:  0.0
# Most probably state:  1000011010111001
# Magnetization:  0.0
# Most probably state:  0110001101111011
# Magnetization:  0.25
# Most probably state:  0111010000100001
# Magnetization:  0.25
# Most probably state:  1010011110000111
# Magnetization:  0.125
# Most probably state:  0010001110011011
# Magnetization:  0.0
# Most probably state:  0111011100101001
# Magnetization:  0.125
# Most probably state:  1000010110111011
# Magnetization:  0.125
# Most probably state:  0110111100010000
# Magnetization:  0.125
# Most probably state:  0110011011101110
# Magnetization:  0.25
# Most probably state:  0111110101101000
# Magnetization:  0.125
# Most probably state:  1110011100011111
# Magnetization:  0.375
# Most probably state:  1110010100011010
# Magnetization:  0.0
# Most probably state:  1100111110010111
# Magnetization:  0.375
# Most probably state:  1010101001110111
# Magnetization:  0.25
# Most probably state:  0101111100011011
# Magnetization:  0.25
# Most probably state:  0100111110111110
# Magnetization:  0.375
# Most probably state:  1110110011111001
# Magnetization:  0.375
# Most probably state:  0001110101110110
# Magnetization:  0.125
# Most probably state:  0000111111100011
# Magnetization:  0.125
# Most probably state:  1001101001010110
# Magnetization:  0.0
# Most probably state:  1101100110010101
# Magnetization:  0.125
# Most probably state:  1011011000001111
# Magnetization:  0.125
# Most probably state:  0001111011101110
# Magnetization:  0.25
# Most probably state:  0100010101111101
# Magnetization:  0.125
# Most probably state:  1011111111100111
# Magnetization:  0.625
# Most probably state:  1010111100011001
# Magnetization:  0.125
# Most probably state:  1010011010011000
# Magnetization:  0.125
# Most probably state:  0001100001011011
# Magnetization:  0.125
# Most probably state:  0011100011011001
# Magnetization:  0.0
# Most probably state:  1111001111110000
# Magnetization:  0.25
# Most probably state:  1010000100000011
# Magnetization:  0.375
# Most probably state:  0100101011100111
# Magnetization:  0.125
# Most probably state:  1001101110110010
# Magnetization:  0.125
# Most probably state:  0110011010111111
# Magnetization:  0.375
# Most probably state:  1110100010101001
# Magnetization:  0.0
# Most probably state:  1110100010010101
# Magnetization:  0.0
# Most probably state:  0001011010001010
# Magnetization:  0.25
# Most probably state:  0110010111000010
# Magnetization:  0.125
# Most probably state:  0111100001011000
# Magnetization:  0.125
# Most probably state:  0101011011011011
# Magnetization:  0.25
# Most probably state:  0101011010110011
# Magnetization:  0.125
# Most probably state:  0011001011100000
# Magnetization:  0.25
# Most probably state:  1111100101111111
# Magnetization:  0.625
# Most probably state:  1010010010011001
# Magnetization:  0.125
# Most probably state:  1110010000100101
# Magnetization:  0.125
# Most probably state:  0000100001010100
# Magnetization:  0.5
# Most probably state:  0110001101001111
# Magnetization:  0.125
# Most probably state:  0000100100100110
# Magnetization:  0.375
# Most probably state:  1110011000011010
# Magnetization:  0.0
# Most probably state:  1101010111100011
# Magnetization:  0.25
# Most probably state:  1101011101101110
# Magnetization:  0.375
# Most probably state:  1000111111001111
# Magnetization:  0.375
# Most probably state:  0110001101011111
# Magnetization:  0.25
# Most probably state:  1111011000110110
# Magnetization:  0.25
# Most probably state:  1011111110010010
# Magnetization:  0.25
# Most probably state:  1000101001111100
# Magnetization:  0.0
# Most probably state:  1000001100111111
# Magnetization:  0.125
# Most probably state:  1111000011001001
# Magnetization:  0.0
# Most probably state:  1100011010110001
# Magnetization:  0.0
# Most probably state:  1011101101111001
# Magnetization:  0.375
# Most probably state:  1010100101011001
# Magnetization:  0.0
# Most probably state:  1100010011011011
# Magnetization:  0.125
# Most probably state:  1001111001111101
# Magnetization:  0.375
# Most probably state:  1110110111111111
# Magnetization:  0.75
# Most probably state:  0101010001001001
# Magnetization:  0.25
# Most probably state:  0110101011001100
# Magnetization:  0.0
# Most probably state:  1100110010100100
# Magnetization:  0.125
# Most probably state:  1110110000000001
# Magnetization:  0.25
# Most probably state:  1000111011110100
# Magnetization:  0.125
# Most probably state:  0001101011111011
# Magnetization:  0.25
# Most probably state:  0111010000000110
# Magnetization:  0.25
# Most probably state:  1010011010000010
# Magnetization:  0.25
# Most probably state:  0110100110001001
# Magnetization:  0.125
# Most probably state:  1011101100000101
# Magnetization:  0.0
# Most probably state:  1101101111000100
# Magnetization:  0.125
# Most probably state:  0011110000101010
# Magnetization:  0.125
# Most probably state:  0100110011101110
# Magnetization:  0.125
# Most probably state:  1101100001110101
# Magnetization:  0.125
# Most probably state:  1111001101101100
# Magnetization:  0.25
# Most probably state:  1000010000000100
# Magnetization:  0.625
# Most probably state:  1100011111011000
# Magnetization:  0.125
# Most probably state:  0101011011001011
# Magnetization:  0.125
# Most probably state:  1001110100100011
# Magnetization:  0.0
# Most probably state:  1110001111011111
# Magnetization:  0.5
# Most probably state:  0100011010001101
# Magnetization:  0.125
# Most probably state:  1000000101110100
# Magnetization:  0.25
# Most probably state:  0001101111100100
# Magnetization:  0.0
# Most probably state:  0010111001111001
# Magnetization:  0.125
# Most probably state:  0001101000011011
# Magnetization:  0.125
# Most probably state:  1100101110111011
# Magnetization:  0.375
# Most probably state:  0010111011111001
# Magnetization:  0.25
# Most probably state:  0000000001010101
# Magnetization:  0.5
# Most probably state:  0011110000100100
# Magnetization:  0.25
# Most probably state:  1011110011100000
# Magnetization:  0.0
# Most probably state:  1110001000100011
# Magnetization:  0.125
# Most probably state:  0100011000100010
# Magnetization:  0.375
# Most probably state:  1100000000111100
# Magnetization:  0.25
# Most probably state:  1010101001011010
# Magnetization:  0.0
# Most probably state:  0001110010110000
# Magnetization:  0.25
# Most probably state:  1001111000010001
# Magnetization:  0.125
# Most probably state:  1100101001010111
# Magnetization:  0.125
# Most probably state:  0001111010110100
# Magnetization:  0.0
# Most probably state:  1100110100111001
# Magnetization:  0.125
# Most probably state:  0101101000110101
# Magnetization:  0.0
# Most probably state:  0001000101010010
# Magnetization:  0.375
# Most probably state:  1010111010100101
# Magnetization:  0.125
# Most probably state:  1111111111100100
# Magnetization:  0.5
# Most probably state:  1100101100001111
# Magnetization:  0.125

# %%
#Circuit size 256
temps = np.linspace(0.01, 15, 20)
df = pd.DataFrame()

magnetization = []
for temp in temps:
    qc = phase_space_sweep(temp, 256)
    state, mag = measure(qc)
    magnetization.append(mag)
df['kT'] = temps
df['Magnetization'] = magnetization

df.to_csv('Circuit 256_Samples 1_statevector.csv')
# Out:
# Most probably state:  1010100100101011
# Magnetization:  0.0
# Most probably state:  1010111100011001
# Magnetization:  0.125
# Most probably state:  1100100100001001
# Magnetization:  0.25
# Most probably state:  1111101111001001
# Magnetization:  0.375
# Most probably state:  1100001000001100
# Magnetization:  0.375
# Most probably state:  0000111100000110
# Magnetization:  0.25
# Most probably state:  1111001110000110
# Magnetization:  0.125
# Most probably state:  0010101001101011
# Magnetization:  0.0
# Most probably state:  0101000100000010
# Magnetization:  0.5
# Most probably state:  0100101010000010
# Magnetization:  0.375
# Most probably state:  0100111011010111
# Magnetization:  0.25
# Most probably state:  0100111010001110
# Magnetization:  0.0
# Most probably state:  0101011110010111
# Magnetization:  0.25
# Most probably state:  1000000001101110
# Magnetization:  0.25
# Most probably state:  1111001011111100
# Magnetization:  0.375
# Most probably state:  0100111000111000
# Magnetization:  0.125
# Most probably state:  1100010100010101
# Magnetization:  0.125
# Most probably state:  0001010111001010
# Magnetization:  0.125
# Most probably state:  0110000110100111
# Magnetization:  0.0
# Most probably state:  0111111001000100
# Magnetization:  0.0

# %%
#Circuit size 512
temps = np.linspace(0.01, 15, 20)
df = pd.DataFrame()

magnetization = []
for temp in temps:
    qc = phase_space_sweep(temp, 512)
    state, mag = measure(qc)
    magnetization.append(mag)
df['kT'] = temps
df['Magnetization'] = magnetization

df.to_csv('Circuit 512_Samples 1_statevector.csv')
# Out:
# Most probably state:  1111100111000001
# Magnetization:  0.125
# Most probably state:  0001011010011001
# Magnetization:  0.125
# Most probably state:  1101011111001110
# Magnetization:  0.375
# Most probably state:  1111010101001110
# Magnetization:  0.25
# Most probably state:  0111011110000011
# Magnetization:  0.125
# Most probably state:  1101001111000100
# Magnetization:  0.0
# Most probably state:  1111010100101011
# Magnetization:  0.25
# Most probably state:  1101010000101000
# Magnetization:  0.25
# Most probably state:  0001101010011100
# Magnetization:  0.125
# Most probably state:  0011110001000001
# Magnetization:  0.25
# Most probably state:  0101000101100011
# Magnetization:  0.125
# Most probably state:  1110110111010010
# Magnetization:  0.25
# Most probably state:  1000110111100010
# Magnetization:  0.0
# Most probably state:  0110000111010100
# Magnetization:  0.125
# Most probably state:  0000100111011000
# Magnetization:  0.25
# Most probably state:  0111000111001011
# Magnetization:  0.125
# Most probably state:  1010011101101101
# Magnetization:  0.25
# Most probably state:  1000001010011000
# Magnetization:  0.375
# Most probably state:  0101100101110101
# Magnetization:  0.125
# Most probably state:  0011010100011111
# Magnetization:  0.125

# %%
# %%time
qc = phase_space_sweep(4, 512)
qc = transpile(qc,sim)
final_counts = sim.run(qc, shots=1).result().get_counts()
prob, state = max(final_counts.values()), max(final_counts, key = final_counts.get)
mag = abs(cal_M(state))
plot_histogram(final_counts)
print(mag)
# Out:
# 0.125
# CPU times: user 25min 31s, sys: 7min 20s, total: 32min 52s
# Wall time: 47min 54s

# %%
plot_histogram(final_counts)
